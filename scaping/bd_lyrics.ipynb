# %%
import pandas as pd

# %%
bob=pd.read_csv('lyrics.csv')

# %%
bob
# Out:
#        Unnamed: 0                                               link  \
# 0               0     ../lyrics/backstreetboys/climbingthewalls.html
# 1               1           ../lyrics/westlife/howtobreakaheart.html
# 2               2                    ../lyrics/deanmartin/iwill.html
# 3               3      ../lyrics/deanmartin/tellyourmotherhello.html
# 4               4           ../lyrics/deanmartin/behonestwithme.html
# ...           ...                                                ...
# 25737       25737               ../lyrics/jasonmraz/whatmamasay.html
# 25738       25738  https://www.azlyrics.com/lyrics/gesaffelstein/...
# 25739       25739             ../lyrics/jasonmraz/aworldwithyou.html
# 25740       25740                ../lyrics/jasonmraz/loveisreal.html
# 25741       25741                   ../lyrics/jasonmraz/gypsymc.html
#
#                        artist               song_name  \
# 0      Backstreet Boys Lyrics      Climbing The Walls
# ...

# %%
bd=bob.copy()

# %%
bd=bd[['artist','song_name','lyrics']]

# %%
bd
# Out:
#                        artist               song_name  \
# 0      Backstreet Boys Lyrics      Climbing The Walls
# 1             Westlife Lyrics    How To Break A Heart
# 2          Dean Martin Lyrics                  I Will
# 3          Dean Martin Lyrics  Tell Your Mother Hello
# 4          Dean Martin Lyrics       Be Honest With Me
# ...                       ...                     ...
# 25737       Jason Mraz Lyrics           What Mama Say
# 25738    Gesaffelstein Lyrics               Blast Off
# 25739       Jason Mraz Lyrics        A World With You
# 25740       Jason Mraz Lyrics            Love Is Real
# 25741       Jason Mraz Lyrics                Gypsy MC
#
#                                                   lyrics
# 0      \n\n[Brian:]\nClose your eyes, make a wish\nTh...
# 1      \n\r\nSince you're not worth my love\nI haven'...
# 2      \n\r\nI don't want to be the one to say I'm go...
# 3      \n\r\nSure I loved the dear money that shines ...
# ...

# %%
bob['artist']=='Bob Dylan Lyrics'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25737    False
# 25738    False
# 25739    False
# 25740    False
# 25741    False
# Name: artist, Length: 25742, dtype: bool

# %%
bd = bd[bd['artist']=='Bob Dylan Lyrics'].reset_index(drop=True)

# %%
bd
# Out:
#                artist                               song_name  \
# 0    Bob Dylan Lyrics                        Corrina, Corrina
# 1    Bob Dylan Lyrics                         It Hurts Me Too
# 2    Bob Dylan Lyrics  The Groom's Still Waiting At The Altar
# 3    Bob Dylan Lyrics                  One More Cup Of Coffee
# 4    Bob Dylan Lyrics             Subterranean Homesick Blues
# ..                ...                                     ...
# 483  Bob Dylan Lyrics                    My One And Only Love
# 484  Bob Dylan Lyrics                          Stormy Weather
# 485  Bob Dylan Lyrics                               Highlands
# 486  Bob Dylan Lyrics                 All I Really Want To Do
# 487  Bob Dylan Lyrics                           Tears Of Rage
#
#                                                 lyrics
# 0    \n\r\nCorrina, Corrina\nGal, where you been so...
# 1    \n\r\nSo run here baby, put your little hands ...
# ...

# %%
bd = bd[['song_name','lyrics']]

# %%
bd
# Out:
#                                   song_name  \
# 0                          Corrina, Corrina
# 1                           It Hurts Me Too
# 2    The Groom's Still Waiting At The Altar
# 3                    One More Cup Of Coffee
# 4               Subterranean Homesick Blues
# ..                                      ...
# 483                    My One And Only Love
# 484                          Stormy Weather
# 485                               Highlands
# 486                 All I Really Want To Do
# 487                           Tears Of Rage
#
#                                                 lyrics
# 0    \n\r\nCorrina, Corrina\nGal, where you been so...
# 1    \n\r\nSo run here baby, put your little hands ...
# 2    \n\r\nPrayed in the ghetto with my face in the...
# 3    \n\r\nYour breath is sweet\r\nYour eyes are li...
# 4    \n\r\nJohnny's in the basement\nMixing up the ...
# ..                                                 ...
# ...

# %%
bd.rename(columns = {'song_name':'title', 'lyrics':'text'}, inplace = True)
# Out:
# C:\Users\duyadong\AppData\Local\Temp\ipykernel_19184\3632295964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd.rename(columns = {'song_name':'title', 'lyrics':'text'}, inplace = True)

# %%
bd
# Out:
#                                       title  \
# 0                          Corrina, Corrina
# 1                           It Hurts Me Too
# 2    The Groom's Still Waiting At The Altar
# 3                    One More Cup Of Coffee
# 4               Subterranean Homesick Blues
# ..                                      ...
# 483                    My One And Only Love
# 484                          Stormy Weather
# 485                               Highlands
# 486                 All I Really Want To Do
# 487                           Tears Of Rage
#
#                                                   text
# 0    \n\r\nCorrina, Corrina\nGal, where you been so...
# 1    \n\r\nSo run here baby, put your little hands ...
# 2    \n\r\nPrayed in the ghetto with my face in the...
# 3    \n\r\nYour breath is sweet\r\nYour eyes are li...
# 4    \n\r\nJohnny's in the basement\nMixing up the ...
# ..                                                 ...
# ...

# %%
bd.to_csv('bob_dylan.csv')
