# %%
#Import important libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
from random import randint
from time import sleep

# %%
url ='https://www.best-poems.net/jorge_luis_borges/index.html'

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
title_soup = soup.select('#content > ul > li:nth-child(31) > a')
title_soup
# Out:
# []

# %%
titl=[]
for i in title_soup:
    t= i.get("href")
    titl.append(t)

titl
# Out:
# []

# %%
# Get all the pages from poemhunter with Mary Oliver's poems:

pages = [] #list of all responses

#start with the first page, that has a slightly different url:
url ='https://www.best-poems.net/jorge_luis_borges/index.html'
print(url)
response = requests.get(url)
print("Status code: " + str(response.status_code))
pages.append(response)


#In this for-loop the pages 2-10 are scraped and put into pages:
for i in range(1,4):
    page= str(i)
    url = 'https://www.best-poems.net/jorge_luis_borges/index.html?page=' + page
    print(url)
    
    response = requests.get(url)
    
    print("Status code: " + str(response.status_code))
    
    # store response into "pages" list
    pages.append(response)
    
    # respectful nap:
    wait_time = randint(1,4000)
    print("I will sleep for " + str(wait_time/1000) + " second/s.")
    sleep(wait_time/1000)
# Out:
# https://www.best-poems.net/jorge_luis_borges/index.html
# Status code: 200
# https://www.best-poems.net/jorge_luis_borges/index.html?page=1
# Status code: 200
# I will sleep for 0.429 second/s.
# https://www.best-poems.net/jorge_luis_borges/index.html?page=2
# Status code: 200
# I will sleep for 3.918 second/s.
# https://www.best-poems.net/jorge_luis_borges/index.html?page=3
# Status code: 200
# I will sleep for 0.002 second/s.

# %%
#Get the urls for the specific poems:

titles=[]
url_list= []

for i in range(len(pages)):
    # parse all pages
    parsed = BeautifulSoup(pages[i].content, "html.parser")
    
    # creating the title soup
    for j in range(1,31):
        title_soup = parsed.select('#content > ul > li:nth-child('+ str(j) +') > a')
    
    #And append every title to the titles list
        for item in title_soup:
            url_list.append(item.get("href"))
            titles.append(item.get_text())

# %%
len(pages)
# Out:
# 4

# %%
len(url_list)
# Out:
# 56

# %%
titles
# Out:
# ['Adam Cast Forth',
#  'Browning Decides To Be A Poet',
#  'Elegy',
#  'History Of The Night',
#  'Instants',
#  'Limits',
#  'Remorse For Any Death',
#  'Shinto',
#  'Susana Soca',
#  'That One',
#  'The Art Of Poetry',
#  'The Other Tiger',
#  'To A Cat',
#  'We are the time. We are the famous',
#  'Adam Cast Forth',
#  'Browning Decides To Be A Poet',
#  'Elegy',
#  'History Of The Night',
#  'Instants',
#  'Limits',
#  'Remorse For Any Death',
#  'Shinto',
#  'Susana Soca',
#  'That One',
#  'The Art Of Poetry',
#  'The Other Tiger',
#  'To A Cat',
#  'We are the time. We are the famous',
#  'Adam Cast Forth',
#  'Browning Decides To Be A Poet',
#  'Elegy',
#  'History Of The Night',
#  'Instants',
#  'Limits',
#  'Remorse For Any Death',
#  'Shinto',
#  'Susana Soca',
#  'That One',
#  'The Art Of Poetry',
#  'The Other Tiger',
#  'To A Cat',
#  'We are the time. We are the famous',
#  'Adam Cast Forth',
#  'Browning Decides To Be A Poet',
#  'Elegy',
#  'History Of The Night',
# ...

# %%
# Now get the poems itself:

poem_soup = []

for url in url_list:
    page = 'https://www.best-poems.net'+str(url) #Create url by means of the url_list
    print(page)
    
    response = requests.get(page)               # Get the soup of the webpage
    print("Status code: " + str(response.status_code))
    
    poem_soup.append(response)                  # Append to poem_soup; later I will get the poems from this soup
    
    # respectful nap:
    wait_time = randint(1,4000)
    print("I will sleep for " + str(wait_time/1000) + " second/s.")
    sleep(wait_time/1000)
# Out:
# https://www.best-poems.net/jorge_luis_borges/adam_cast_forth.html
# Status code: 200
# I will sleep for 0.572 second/s.
# https://www.best-poems.net/jorge_luis_borges/browning_decides_to_be_a_poet.html
# Status code: 200
# I will sleep for 3.749 second/s.
# https://www.best-poems.net/jorge_luis_borges/elegy.html
# Status code: 200
# I will sleep for 3.595 second/s.
# https://www.best-poems.net/jorge_luis_borges/poem10435.html
# Status code: 200
# I will sleep for 0.207 second/s.
# https://www.best-poems.net/jorge_luis_borges/instants.html
# Status code: 200
# I will sleep for 0.777 second/s.
# https://www.best-poems.net/jorge_luis_borges/limits.html
# Status code: 200
# I will sleep for 1.026 second/s.
# https://www.best-poems.net/jorge_luis_borges/remorse_for_any_death.html
# Status code: 200
# I will sleep for 1.87 second/s.
# https://www.best-poems.net/jorge_luis_borges/shinto.html
# Status code: 200
# I will sleep for 3.365 second/s.
# ...

# %%
poems_text = []

for i in range(len(poem_soup)):
    # parse all pages
    parsed = BeautifulSoup(poem_soup[i].content, "html.parser")
    
    # creating the poem soup
    #beatiful_poem_soup = parsed.select('#content')
    text = parsed.select('#content')[0].get_text()
    poems_text.append(text)

# %%
poems_text
# Out:
# ["\nWas there a Garden or was the Garden a dream?\nAmid the fleeting light, I have slowed myself and queried,\nAlmost for consolation, if the bygone period\nOver which this Adam, wretched now, once reigned supreme,\nMight not have been just a magical illusion\nOf that God I dreamed. Already it's imprecise\nIn my memory, the clear Paradise,\nBut I know it exists, in flower and profusion,\nAlthough not for me. My punishment for life\nIs the stubborn earth with the incestuous strife\nOf Cains and Abels and their brood; I await no pardon.\nYet, it's much to have loved, to have known true joy,\nTo have had -- if only for just one day --\nThe experience of touching the living Garden.",
# ...

# %%
#Put this all together in a dataframe and save it in a csv-file:
df = pd.DataFrame({'title':titles, 'text':poems_text})
df
# Out:
#                                  title  \
# 0                      Adam Cast Forth
# 1        Browning Decides To Be A Poet
# 2                                Elegy
# 3                 History Of The Night
# 4                             Instants
# 5                               Limits
# 6                Remorse For Any Death
# 7                               Shinto
# 8                          Susana Soca
# 9                             That One
# 10                   The Art Of Poetry
# 11                     The Other Tiger
# 12                            To A Cat
# 13  We are the time. We are the famous
# 14                     Adam Cast Forth
# 15       Browning Decides To Be A Poet
# 16                               Elegy
# 17                History Of The Night
# 18                            Instants
# 19                              Limits
# 20               Remorse For Any Death
# 21                              Shinto
# 22                         Susana Soca
# ...

# %%
df.to_csv('jorge_luis_borges.csv', index=False)
